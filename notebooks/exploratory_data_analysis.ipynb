# %% [markdown]
# # Hand Gesture Dataset - Exploratory Data Analysis (EDA)
#
# This notebook analyzes the 21 3D hand landmark dataset collected for real-time game control.
# It inspects class distributions, landmark coordinate distributions, engineered feature correlations, and PCA class separability.

# %%
import os
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Add root directory to sys.path
sys.path.append('..')
from src.exploratory_data_analysis import GestureEDA

# %matplotlib inline

# %%
# Run EDA Pipeline
eda = GestureEDA(raw_csv_path='../data/raw/gestures.csv', output_dir='../reports')
summary = eda.run_analysis()
print('EDA Summary:', summary)
